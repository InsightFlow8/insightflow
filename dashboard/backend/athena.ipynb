# %%
# Test the connection first
from analysis_athena import test_connection
# test_connection()

# Test individual analyses
from analysis_athena import test_product_affinity, test_customer_journey, test_lifetime_value, test_churn_analysis
# test_churn_analysis()

# Or run all tests
from analysis_athena import test_athena_analysis
test_athena_analysis()
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# 🚀 Starting Athena Analysis Test (Raw Data)
# ==================================================
# 📊 Initializing Athena Analyzer...
# INFO:analysis_athena:✅ Successfully connected to S3 bucket: insightflow-dev-raw-bucket
# INFO:analysis_athena:Executing Athena query: product_affinity
# INFO:analysis_athena:📋 No cached result found for query hash: 0631e7f6489be997713f3ccfd10130f2
# ✅ Athena Analyzer initialized successfully
# 🗑️ Clearing cache for fresh results...
# 🗑️ Deleted: athena-cache/0631e7f6489be997713f3ccfd10130f2.parquet
# 🗑️ Deleted: athena-cache/4e0de0f8f9e0e87ea0a100e58e7f5577.parquet
# 🗑️ Deleted: athena-cache/cf5f44a4d2e878241ade86ae54de3d22.parquet
# ✅ Cleared 3 cached results
# ✅ Cache cleared successfully
#
# 🔗 Testing Product Affinity Analysis...
# INFO:analysis_athena:Query execution ID: 25de727a-6f72-44ab-a1b4-2084c3213076
# INFO:analysis_athena:Query completed successfully. Returned 190 rows
# INFO:analysis_athena:💾 Saved result to cache: athena-cache/0631e7f6489be997713f3ccfd10130f2.parquet
# ✅ Product Affinity Analysis completed - 190 product pairs found
# 📊 Displaying Product Affinity Graph:
# INFO:analysis_athena:Executing Athena query: customer_journey
# INFO:analysis_athena:📋 No cached result found for query hash: 62e39d689ab7de59113884e49dc0a862
# INFO:analysis_athena:Query execution ID: 98d927be-b27e-412e-8e31-851b5c90d552
# 🏆 Top 10 Product Pairs:
#             product1_name         product2_name  pair_count
# 0  Bag of Organic Bananas  Organic Hass Avocado      255767
# 1  Bag of Organic Bananas  Organic Strawberries      253911
# 2    Organic Strawberries                Banana      233881
# 3                  Banana       Organic Avocado      219829
# 4    Organic Baby Spinach                Banana      209872
# 5  Bag of Organic Bananas  Organic Baby Spinach      203212
# 6            Strawberries                Banana      172934
# 7                  Banana           Large Lemon      170226
# 8    Organic Strawberries  Organic Hass Avocado      165710
# 9  Bag of Organic Bananas   Organic Raspberries      165220
#
# 👥 Testing Customer Journey Analysis...
# INFO:analysis_athena:Query completed successfully. Returned 1 rows
# INFO:analysis_athena:💾 Saved result to cache: athena-cache/62e39d689ab7de59113884e49dc0a862.parquet
# ✅ Customer Journey Analysis completed - 1 customers analyzed
# 📊 Displaying Customer Journey Graph:
# INFO:analysis_athena:Executing Athena query: lifetime_value
# INFO:analysis_athena:📋 No cached result found for query hash: cacdbb9a0d0373a40215816cce7a13db
# INFO:analysis_athena:Query execution ID: b26f54f8-93c5-4bfe-ad8e-22824ec11903
# 📈 Customer Statistics:
# Total customers: 1
# Average orders per customer: 77682.00
# Average items per customer: 1888180.00
#
# 💰 Testing Lifetime Value Analysis...
# INFO:analysis_athena:Query completed successfully. Returned 9990 rows
# INFO:analysis_athena:💾 Saved result to cache: athena-cache/cacdbb9a0d0373a40215816cce7a13db.parquet
# ✅ Lifetime Value Analysis completed - 9990 customers analyzed
# 📊 Displaying Lifetime Value Graph:
# INFO:analysis_athena:Executing Athena query: churn_analysis
# INFO:analysis_athena:Query execution ID: 1ebd7f64-17df-4fda-87eb-f2bcc7230378
# 🎯 Customer Segments:
#   High Value: 9580 customers (95.9%)
#   Medium Value: 394 customers (3.9%)
#   Low Value: 16 customers (0.2%)
#
# 📉 Testing Churn Analysis...
# INFO:analysis_athena:Query completed successfully. Returned 9990 rows
# 📊 Churn Analysis Data: 9990 rows
# 📈 Total Orders Range: 4 - 100
# 📅 Days Between Range: 0.3 - 30.0
# 📊 Sample Data:
#    user_id  total_orders  avg_days_between  max_days_between  std_days_between
# 0   110935            45          7.954545              28.0          4.605126
# 1    14956            28         11.259259              22.0          4.502927
# 2   102651            27         11.230769              30.0          8.514964
# 3    30798            56          2.800000              12.0          1.899318
# 4    98063             5         30.000000              30.0          0.000000
# 📊 Order Count Distribution:
# total_orders
# 4      1230
# 5       932
# 6       759
# 7       737
# 8       554
#        ...
# 96        2
# 97        7
# 98        2
# 99        3
# 100      65
# Name: count, Length: 97, dtype: int64
# 📅 Days Since Prior Analysis:
#   - Customers with avg_days_between > 0: 9990
#   - Customers with max_days_between > 0: 9990
#   - Customers with std_days_between > 0: 9683
# 📊 Value Ranges:
#   - avg_days_between: 0.33 - 30.00
#   - max_days_between: 1.00 - 30.00
#   - std_days_between: 0.00 - 17.32
# 📊 Sample Customers with Different Values:
#    user_id  total_orders  avg_days_between  max_days_between  std_days_between
# 0   110935            45          7.954545              28.0          4.605126
# 1    14956            28         11.259259              22.0          4.502927
# 2   102651            27         11.230769              30.0          8.514964
# 3    30798            56          2.800000              12.0          1.899318
# 4    98063             5         30.000000              30.0          0.000000
# 📊 Customers with Multiple Orders: 9990
#   - Order range: 4 - 100
#   - Days range: 0.3 - 30.0
#   - Max days range: 1.0 - 30.0
#   - Sample multi-order customers:
#    user_id  total_orders  avg_days_between  max_days_between  std_days_between
# 0   110935            45          7.954545              28.0          4.605126
# 1    14956            28         11.259259              22.0          4.502927
# 2   102651            27         11.230769              30.0          8.514964
# 📊 All Order Counts Found:
# total_orders
# 4      1230
# 5       932
# 6       759
# 7       737
# 8       554
#        ...
# 96        2
# 97        7
# 98        2
# 99        3
# 100      65
# Name: count, Length: 97, dtype: int64
# 📊 Customers with Days Data: 9990
#   - Days range: 0.3 - 30.0
#   - Max days range: 1.0 - 30.0
# 📊 Cleaned DataFrame Shape: (9990, 5)
# 📊 Cleaned DataFrame Columns: ['user_id', 'total_orders', 'avg_days_between', 'max_days_between', 'std_days_between']
# 📊 Sample Cleaned Data:
#    user_id  total_orders  avg_days_between  max_days_between  std_days_between
# 0   110935            45          7.954545              28.0          4.605126
# 1    14956            28         11.259259              22.0          4.502927
# 2   102651            27         11.230769              30.0          8.514964
# 3    30798            56          2.800000              12.0          1.899318
# 4    98063             5         30.000000              30.0          0.000000
# 📊 Order Count Distribution:
# total_orders
# 4      1230
# 5       932
# 6       759
# 7       737
# 8       554
#        ...
# 96        2
# 97        7
# 98        2
# 99        3
# 100      65
# Name: count, Length: 97, dtype: int64
# 📅 Days Distribution Sample:
# avg_days_between
# 0.333333    1
# 0.571429    1
# 0.666667    1
# 0.707071    1
# 1.000000    1
# 1.232323    1
# 1.250000    1
# 1.290698    1
# 1.300000    1
# 1.333333    1
# Name: count, dtype: int64
# 📊 Histogram Data Debug:
#   - Days data length: 9990
#   - Days data range: 0.33 - 30.00
#   - Days data sample: [7.954545454545454, 11.25925925925926, 11.23076923076923, 2.8, 30.0, 19.714285714285715, 15.285714285714286, 11.176470588235292, 18.3, 29.75]
#   - Filtered days data length (excluding 0): 9990
#   - Filtered days data range: 0.33 - 30.00
# ✅ Churn Analysis completed - 9990 customers analyzed
# 📊 Displaying Churn Analysis Graph:
# ⚠️ Churn Risk Statistics:
# Average days between orders: 15.5 days
# Max days between orders: 30.0 days
# Customers with high churn risk (>30 days avg): 0
#
# 🎉 All tests completed!
# ==================================================

# %%
def load_data_from_local_files():
    """Fallback: Load data from local CSV files"""
    # Use imba_data directory - check if running in Docker container first
    if os.path.exists("/app/imba_data"):
        data_path = "/app/imba_data"
    else:
        data_path = "../../imba_data"
    
    try:
        # Define file paths based on actual files in imba_data/
        orders_path = os.path.join(data_path, "orders.csv")
        products_path = os.path.join(data_path, "products.csv")
        departments_path = os.path.join(data_path, "departments.csv")
        aisles_path = os.path.join(data_path, "aisles.csv")
        order_products_prior_path = os.path.join(data_path, "order_products__prior.csv.gz")
        order_products_train_path = os.path.join(data_path, "order_products__train.csv.gz")
        
        # Check if files exist
        required_files = [orders_path, products_path, departments_path, aisles_path, 
                            order_products_prior_path, order_products_train_path]
        
        missing_files = [f for f in required_files if not os.path.exists(f)]
        if missing_files:
            raise FileNotFoundError(f"Missing data files: {missing_files}")
        
        # Load all CSV files
        orders = pd.read_csv(orders_path)
        products = pd.read_csv(products_path)
        departments = pd.read_csv(departments_path)
        aisles = pd.read_csv(aisles_path)
        try:
            order_products_prior = pd.read_csv(order_products_prior_path, compression='gzip')
        except Exception as e:
            order_products_prior = pd.read_csv(order_products_prior_path)
        
        try:
            order_products_train = pd.read_csv(order_products_train_path, compression='gzip')
        except Exception as e:
            order_products_train = pd.read_csv(order_products_train_path)
        
        # Filter orders to keep only user_id < 10000 (consistent with backend)
        orders = orders[orders['user_id'] < 20000]
        
        # Get the list of order_ids from filtered orders
        valid_order_ids = orders['order_id'].unique()
        
        # Filter order_products to keep only records where order_id exists in filtered orders
        order_products_prior = order_products_prior[order_products_prior['order_id'].isin(valid_order_ids)]
        order_products_train = order_products_train[order_products_train['order_id'].isin(valid_order_ids)]
        
        # Combine order products data
        order_products = pd.concat([order_products_prior, order_products_train], ignore_index=True)
        
        # Merge all data
        df = order_products.merge(orders, on='order_id', how='left')
        df = df.merge(products, on='product_id', how='left')
        df = df.merge(departments, on='department_id', how='left')
        df = df.merge(aisles, on='aisle_id', how='left')
        
        return df, orders, products, departments, aisles
        
    except Exception as e:
        # Return empty DataFrames with proper structure to prevent errors
        empty_df = pd.DataFrame()
        empty_orders = pd.DataFrame(columns=['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order'])
        empty_products = pd.DataFrame(columns=['product_id', 'product_name', 'aisle_id', 'department_id'])
        empty_departments = pd.DataFrame(columns=['department_id', 'department'])
        empty_aisles = pd.DataFrame(columns=['aisle_id', 'aisle'])
        
        return empty_df, empty_orders, empty_products, empty_departments, empty_aisles

# %%
from data_loader import test_products_loading
test_products_loading()
# Out:
# 🧪 Testing products loading with pagination...
# ✅ Successfully loaded 49639 products
# 📊 Sample products:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#                         aisle  department_id department
# 0               cookies cakes             19     snacks
# 1           spices seasonings             13     pantry
# 2                         tea              7  beverages
# 3                frozen meals              1     frozen
# 4  marinades meat preparation             13     pantry
# 📈 Product count range: 1 - 49688
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49634       49684            Vodka Triple Distilled Twist of Vanilla
# 49635       49685                 En Croute Roast Hazelnut Cranberry
# 49636       49686                                   Artisan Baguette
# 49637       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49638       49688                             Fresh Foaming Cleanser
#
#        aisle_id                       aisle  department_id     department
# 0            61               cookies cakes             19         snacks
# 1           104           spices seasonings             13         pantry
# 2            94                         tea              7      beverages
# 3            38                frozen meals              1         frozen
# 4             5  marinades meat preparation             13         pantry
# ...         ...                         ...            ...            ...
# 49634       124                     spirits              5        alcohol
# 49635        42     frozen vegan vegetarian              1         frozen
# 49636       112                       bread              3         bakery
# 49637        41               cat food care              8           pets
# 49638        73                 facial care             11  personal care
#
# [49639 rows x 6 columns]
